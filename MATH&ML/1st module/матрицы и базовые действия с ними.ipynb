# %%
import numpy as np

# %%
A = np.array([
    [1, -5, 3], 
    [2, 2, 1],
    [0, 3, 1],
    [2, 4, 12]
])
A
# Out:
# array([[ 1, -5,  3],
#        [ 2,  2,  1],
#        [ 0,  3,  1],
#        [ 2,  4, 12]])

# %%
A.shape
## (4, 3)
print('a_23=', A[1, 2], 'a_32=', A[2, 1], 'a_33=', A[2,2])
## a_23= 1 a_32= 3 a_33= 1
# Out:
# a_23= 1 a_32= 3 a_33= 1
