# %%
import numpy as np

# %%
v_1 = np.array([-1,2,-7,9]).T
v_2 = np.array([2,8,2,-1]).T
s = np.dot(v_1, v_2)
s
# Out:
# -9

# %%
A = np.array([[1,1],[1,2]])
G = A.T@A
G
# Out:
# array([[2, 3],
#        [3, 5]])

# %%
A = np.array([[1,2],[3,7]])
A_inv = np.linalg.inv(A)
A_inv
# Out:
# array([[ 7., -2.],
#        [-3.,  1.]])

# %%
A = np.array([[2,10,-2],[3,2,-2],[8,14,-6]]).T
np.linalg.matrix_rank(A)
# Out:
# 2

# %%
A = np.array([[1,2],[-3,1],[1,2],[1,-1]])
A
# Out:
# array([[ 1,  2],
#        [-3,  1],
#        [ 1,  2],
#        [ 1, -1]])

# %%
G = A.T@A
G
# Out:
# array([[12,  0],
#        [ 0, 10]])

# %%
G_inv = np.linalg.inv(G)
G_inv
# Out:
# array([[0.08333333, 0.        ],
#        [0.        , 0.1       ]])

# %%
b = np.array([[1],[4],[5],[0]])
b
# Out:
# array([[1],
#        [4],
#        [5],
#        [0]])

# %%
h = A.T@b

# %%
G_inv@h
# Out:
# array([[-0.5],
#        [ 1.6]])
