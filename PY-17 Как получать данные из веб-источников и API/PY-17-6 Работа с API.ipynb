# %% [markdown]
# # <center> Работа с API
#
# >✍ В предыдущих разделах мы собирали полезную информацию с различных сайтов.
#
# >Вы могли убедиться, что поиск необходимой информации с выделением правильных тегов — довольно трудоёмкая задача. Кроме того, подобные программы могут ломаться в случаях, когда меняется дизайн сайта, его разметка или владельцы сайтов защищаются от ботов капчей.
#
# К счастью, многие крупные сайты предоставляют доступ к так называемым API (англ. Application Programming Interface, рус. Интерфейс Прикладного Программирования).
#
# > API — это специальные разделы сайта, где информацию можно получать без разметки, а формат запросов и ответов зафиксирован. API созданы для того, чтобы облегчить взаимодействие с сайтом для сторонних разработчиков.
#
# К примеру, мы уже видели, как ресурс [Курсы валют ЦБ РФ в XML и JSON](https://www.cbr-xml-daily.ru/) возвращает данные о валютах в JSON-формате. Это пример API.
#
# Рассмотрим на примере социальной сети ВКонтакте особенности API, характерные для более крупных сайтов.
#
# ## <center>КЛЮЧ АВТОРИЗАЦИИ
#
# Для того чтобы начать работать с API, обычно необходимо получить сервисный ключ авторизации — токен.
#
# >Токен — это средство идентификации пользователя или отдельного сеанса работы в компьютерных сетях и приложениях. Различают программные и аппаратные токены.
# Мы будем использовать программный токен, который обычно представляет собой зашифрованную последовательность символов, позволяющую точно идентифицировать объект и определить уровень его привилегий. Он генерируется системой авторизации и привязывается к конкретному сеансу работы, клиенту сети или пакету данных.
#
# Авторизация применяется практически во всех API, чтобы отдавать данные только их владельцу или контролировать количество запросов в единицу времени.
#
# Сервисный токен для API ВКонтакте для нашей задачи создаётся вместе с новым приложением. Приложение мы делать, конечно, не будем. Оно нужно только для получения токена, чтобы сделать необходимые выгрузки.
#
# Зайдите на [страницу](https://vk.com/editapp?act=create), чтобы создать приложение (вы должны быть авторизованы ВКонтакте). Дайте приложению любое название и в разделе Платформа поставьте отметку выбора напротив значения Standalone-приложение:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Подтвердив создание приложения на сайте в приложении ВКонтакте или по СМС, зайдите в Настройки. Нужный нам токен лежит в поле Сервисный ключ доступа:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## <center>ПЕРВЫЕ ЗАПРОСЫ К API
#
# Чтобы познакомиться с работой API, мы будем получать данные для статистических отчётов произвольной группы, например данные о соотношении мужчин и женщин, статистику географии пользователей и т. п.
#
# Сначала рассмотрим работу API на простом примере, на основе которого работают многие системы.
#
# Сделаем наш первый запрос из браузера.
#
# Перейдите по следующей ниже ссылке в браузере, подставив вместо слова TOKEN ваш персональный сервисный ключ доступа (токен), полученный на предыдущем шаге:
#
# [ссылка](https://api.vk.com/method/users.get?user_id=1&v=5.95&access_token=f478c980f478c980f478c980c6f76a3956ff478f478c980907c3d0e0c0d3721b1596fc9)

# %% [markdown]
# Результат:
#
# {"response":[{"id":1,"first_name":"Павел","last_name":"Дуров","can_access_closed":true,"is_closed":false}]}

# %% [markdown]
# Итак, мы сделали GET-запрос к API ВКонтакте, который состоит из следующих элементов:
#
# * https://api.vk.com/method — домен и URL запроса API; обычно не меняется;
# * users.get — название метода, который отдаёт определённый отчёт, в нашем случае это метод для получения информации о пользователе;
# * user_id и v — параметры запроса: идентификатор пользователя, о котором хотим получить информацию (в нашем примере мы запрашиваем информацию о первом пользователе), и номер версии API;
# * token — токен, который выдаётся только пользователям, имеющим право просматривать определённые данные, например показания счётчиков Яндекс.
#
# Метрики вашего проекта; на все остальные запросы без корректного токена система отвечает отказом.
# Если мы обратимся к [документации метода users.get](https://vk.com/dev/users.get), то увидим, что в ней описано множество других параметров, которые можно получить о пользователе (дата рождения, пол, родной город и другие) — словом, всё то, что мы видим на странице пользователя в интерфейсе или приложении ВКонтакте (конечно, если пользователь их указал).
#
# Добавим к запросу дату рождения и пол (согласно документации, эти параметры надо перечислять в поле fields):
#
# [Запрос](https://api.vk.com/method/users.get?user_id=1&v=5.95&fields=sex,bdate&access_token=f478c980f478c980f478c980c6f76a3956ff478f478c980907c3d0e0c0d3721b1596fc9)

# %% [markdown]
# До этого момента мы делали запросы в браузере — теперь давайте выполним запросы из кода.
#
# ## <center> ЗАПРОС К API ИЗ КОДА
#
# Продолжаем пользоваться всё той же библиотекой requests.

# %%
import requests # Импортируем модуль requests
token = 'f478c980f478c980f478c980c6f76a3956ff478f478c980907c3d0e0c0d3721b1596fc9' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/users.get' # Указываем адрес страницы к которой делаем запрос
params = {'user_id': 1, 'v': 5.95, 'fields': 'sex,bdate', 'access_token': token, 'lang': 'ru'} # Перечисляем параметры нашего запроса в словаре params
response = requests.get(url, params=params) # Отправляем запрос
print(response.text) # Выводим текст ответа на экран
# Out:
# {"response":[{"id":1,"bdate":"10.10.1984","sex":2,"first_name":"Павел","last_name":"Дуров","can_access_closed":true,"is_closed":false}]}

# %% [markdown]
# Мы получили строку в JSON-формате, которую можно преобразовать в словарь с помощью метода json(), после чего можно с лёгкостью обращаться к различным полям.
#
# Словари нагляднее выводить с помощью функции pprint(), которую мы уже использовали ранее:

# %%
from pprint import pprint # Импортируем функцию pprint()
pprint(response.json()) # Выводим содержимое словаря, содержащего ответ, на экран
# Out:
# {'response': [{'bdate': '10.10.1984',
#                'can_access_closed': True,
#                'first_name': 'Павел',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Дуров',
#                'sex': 2}]}

# %% [markdown]
# Как вы видите, по ключу response мы можем получить список, в котором хранятся словари, содержащие информацию о запрошенных нами пользователях. Мы запросили информацию лишь об одном из них, поэтому список содержит только один элемент. Извлечём его:

# %%
user = response.json()['response'][0] # Извлекаем из словаря по ключу response информацию о первом пользователе
print(user['bdate']) # Выводим дату рождения первого пользователя на экран
print(user['first_name'])
# Out:
# 10.10.1984
# Павел

# %% [markdown]
# Метод users.get() позволяет запрашивать информацию о множестве (до 1 000) пользователей одновременно. Для этого нужно использовать параметр user_ids и передавать id через запятую в строковом формате. Например, чтобы получить информацию о пользователях с id=1, id=2, id=3, необходимо передать значение параметра user_ids='1,2,3'.
#
# Попробуем это сделать:

# %%
ids = ",".join(map(str, range(1, 4))) # Формируем строку, содержащую информацию о поле id первых трёх пользователей
params = {'user_ids': ids, 'v': 5.95, 'fields': 'bdate', 'access_token': token, 'lang': 'ru'} # Формируем строку параметров
pprint(requests.get(url, params=params).json()) # Посылаем запрос, полученный ответ в формате JSON-строки преобразуем в словарь и выводим на экран его содержимое, используя функцию pprint()
# Out:
# {'response': [{'bdate': '10.10.1984',
#                'can_access_closed': True,
#                'first_name': 'Павел',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Дуров'},
#               {'bdate': '14.2',
#                'can_access_closed': False,
#                'first_name': 'Александра',
#                'id': 2,
#                'is_closed': True,
#                'last_name': 'Владимирова'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 3,
#                'is_closed': False,
#                'last_name': ''}]}

# %% [markdown]
# ### Задание 6.2
#
# Используя API, определите долю женщин (sex=1) среди пользователей с id от 1 до 500. Иногда будут попадаться пользователи, у которых пол не указан (sex=0), — таких пользователей не нужно учитывать в общем числе.
#
# В ответе укажите число, округлив до двух знаков после точки-разделителя, например, 0.55.

# %%
ids = ",".join(map(str, range(1, 501)))
params = {'user_ids': ids, 'v': 5.95, 'fields': 'sex', 'access_token': token, 'lang': 'ru'}
response = requests.get(url, params=params).json()['response']
men=women=0
for elem in response:
    if elem['sex'] == 2:
        men+=1
    elif elem['sex'] == 1:
        women+=1
    else:
        continue
print(round(women/(men+women),2))
# Out:
# 0.48

# %% [markdown]
# ## <center> СБОР ИНФОРМАЦИИ ИЗ ГРУПП
#
# В одном из предыдущих юнитов в качестве примера мы собрали информацию о небольшом количестве пользователей. Теперь перейдём к более реальной задаче — сбору данных о пользователях группы ВКонтакте.
#
# Стоит отметить, что есть много сервисов, которые выгружают похожую статистику из соцсетей. Однако им свойственны недостатки универсальных решений:
#
# * не учитываются все особенности вашего проекта;
# * используется фиксированный набор метрик, дополнительную обработку данных приходится делать вам;
# * не всегда бесплатны и вряд ли позволят работать с большими объёмами данных.
#
# Теперь мы научимся считать произвольные метрики групп, собирая данные из API и работая с двумя ограничениями, которые свойственны практически всем системам:
#
# * ограничение на количество вызовов в единицу времени;
# * ограничение на количество выгружаемых строк за один запрос.
#
# Ограничение на количество запросов в единицу времени сделано для того, чтобы избежать чрезмерной нагрузки на серверы системы. В ряде случаев небольшое количество отчётов можно выгрузить и уложиться в действующий лимит.
#
# Однако второе ограничение не удастся обойти в случае выгрузки больших отчётов. Например, чтобы получить список всех пользователей популярной группы, серверу, возможно, придётся отправить ответ, содержащий миллионы записей.
# ___________________________________________________________________________________________________________________________________________________
# Давайте рассмотрим, как работать с этими ограничениями на примере выгрузки списка пользователей группы https://vk.com/vk социальной сети ВКонтакте.
#
# Обратимся к документации, чтобы узнать, какие методы нам доступны для групп, — для получения списка пользователей группы доступен метод groups.getMembers.
#
# Согласно документации, обязательным параметром данного метода является group_id — идентификатор, или короткое имя, группы. В нашем случае это vk: https://vk.com/vk. Протестируем, как работает метод в самом простом случае, — получим id участников группы:

# %%
import requests # Импортируем модуль requests
token = 'f478c980f478c980f478c980c6f76a3956ff478f478c980907c3d0e0c0d3721b1596fc9' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес обращения
params = {'group_id': 'vk', 'v': 5.95, 'access_token': token} # Формируем строку параметров
response = requests.get(url, params = params) # Посылаем запрос
data = response.json() # Ответ сохраняем в переменной data в формате словаря
print(data) # Выводим содержимое переменной data на экран (отображён фрагмент)
# Out:
# {'response': {'count': 13166494, 'items': [6, 19, 47, 54, 79, 177, 198, 212, 219, 239, 243, 345, 407, 421, 450, 467, 485, 510, 550, 619, 640, 690, 702, 721, 804, 809, 831, 832, 834, 847, 900, 905, 907, 914, 930, 943, 952, 958, 966, 976, 979, 1000, 1018, 1023, 1032, 1033, 1038, 1039, 1059, 1097, 1131, 1139, 1140, 1159, 1174, 1185, 1188, 1301, 1333, 1334, 1336, 1351, 1381, 1386, 1388, 1406, 1411, 1418, 1432, 1494, 1503, 1531, 1550, 1568, 1586, 1590, 1593, 1598, 1610, 1615, 1632, 1634, 1650, 1679, 1690, 1697, 1698, 1699, 1700, 1721, 1740, 1754, 1796, 1814, 1820, 1829, 1834, 1839, 1840, 1843, 1858, 1863, 1869, 1887, 1889, 1917, 1943, 1947, 1955, 1969, 2019, 2028, 2050, 2051, 2052, 2059, 2077, 2103, 2136, 2150, 2195, 2201, 2230, 2236, 2273, 2281, 2296, 2298, 2376, 2389, 2395, 2403, 2412, 2436, 2456, 2466, 2470, 2484, 2515, 2539, 2571, 2576, 2592, 2601, 2622, 2644, 2654, 2692, 2706, 2745, 2755, 2767, 2787, 2797, 2827, 2858, 2896, 2909, 2919, 2922, 2953, 2962, 2982, 3001, 3006, 3041, 3130, 3135, 3172, 3186, 3203, 3231, 3250, 3254, 3316, 3320, 3321, 3328, 3331, 3332, 3364, 3372, 3373, 3384, 3388, 3402, 3420, 3422, 3427, 3436, 3450, 3458, 3472, 3483, 3486, 3491, 3492, 3520, 3545, 3556, 3581, 3626, 3637, 3646, 3653, 3657, 3658, 3675, 3684, 3690, 3697, 3713, 3719, 3786, 3820, 3824, 3836, 3837, 3851, 3863, 3904, 3909, 3938, 3948, 3979, 4004, 4010, 4023, 4026, 4041, 4047, 4048, 4108, 4130, 4150, 4157, 4169, 4189, 4192, 4236, 4262, 4282, 4326, 4378, 4439, 4440, 4447, 4485, 4505, 4521, 4528, 4530, 4537, 4543, 4554, 4558, 4563, 4564, 4583, 4599, 4601, 4640, 4668, 4669, 4670, 4672, 4689, 4693, 4728, 4731, 4748, 4754, 4767, 4769, 4790, 4818, 4828, 4857, 4862, 4866, 4881, 4921, 4923, 4928, 4947, 4981, 5011, 5017, 5067, 5073, 5161, 5166, 5183, 5262, 5273, 5280, 5286, 5386, 5387, 5392, 5394, 5399, 5401, 5430, 5432, 5436, 5438, 5472, 5527, 5546, 5547, 5585, 5590, 5597, 5606, 5615, 5629, 5634, 5665, 5701, 5733, 5768, 5775, 5793, 5803, 5819, 5846, 5850, 5896, 5914, 5916, 5932, 5944, 5959, 5965, 5990, 5991, 5993, 5997, 6000, 6021, 6037, 6046, 6086, 6099, 6107, 6111, 6154, 6161, 6167, 6181, 6186, 6187, 6203, 6260, 6265, 6293, 6323, 6333, 6339, 6379, 6380, 6390, 6492, 6520, 6547, 6557, 6564, 6595, 6604, 6627, 6635, 6670, 6683, 6689, 6701, 6703, 6709, 6715, 6797, 6801, 6862, 6950, 6960, 6994, 7012, 7040, 7050, 7052, 7068, 7099, 7112, 7115, 7117, 7188, 7200, 7208, 7226, 7227, 7286, 7290, 7338, 7402, 7404, 7408, 7428, 7451, 7481, 7492, 7500, 7525, 7543, 7547, 7557, 7595, 7615, 7652, 7661, 7725, 7737, 7755, 7768, 7777, 7830, 7833, 7847, 7855, 7858, 7860, 7962, 7982, 7998, 8019, 8080, 8093, 8149, 8157, 8166, 8167, 8181, 8182, 8194, 8195, 8201, 8224, 8240, 8266, 8273, 8298, 8310, 8321, 8323, 8347, 8348, 8377, 8398, 8418, 8422, 8436, 8443, 8479, 8484, 8505, 8518, 8536, 8544, 8576, 8610, 8636, 8642, 8656, 8658, 8704, 8718, 8727, 8738, 8752, 8777, 8792, 8813, 8875, 8883, 8909, 8910, 8937, 8959, 9000, 9014, 9016, 9079, 9095, 9100, 9110, 9111, 9115, 9173, 9187, 9189, 9222, 9246, 9256, 9352, 9399, 9412, 9413, 9435, 9444, 9447, 9450, 9459, 9466, 9499, 9527, 9532, 9536, 9547, 9556, 9566, 9569, 9571, 9579, 9699, 9723, 9737, 9741, 9748, 9775, 9778, 9782, 9847, 9894, 9900, 9954, 9981, 9993, 10010, 10090, 10117, 10162, 10217, 10272, 10284, 10286, 10302, 10350, 10351, 10354, 10365, 10366, 10376, 10516, 10518, 10570, 10596, 10607, 10615, 10621, 10639, 10682, 10697, 10741, 10749, 10767, 10811, 10833, 10887, 10919, 10955, 10956, 10961, 10972, 10999, 11027, 11064, 11068, 11081, 11084, 11150, 11187, 11191, 11236, 11243, 11271, 11303, 11420, 11446, 11451, 11483, 11568, 11649, 11723, 11727, 11747, 11754, 11763, 11768, 11782, 11865, 11964, 11983, 12005, 12029, 12036, 12097, 12133, 12150, 12159, 12172, 12213, 12252, 12255, 12264, 12316, 12325, 12332, 12345, 12353, 12367, 12407, 12441, 12448, 12454, 12456, 12473, 12477, 12545, 12560, 12570, 12617, 12637, 12638, 12707, 12716, 12718, 12736, 12748, 12756, 12762, 12803, 12808, 12817, 12859, 12892, 12922, 12932, 12952, 12957, 12982, 130 ...

# %% [markdown]
# По ключу count мы можем получить общее число участников группы, а список по ключу items хранит их id. Посмотрим на него поближе:

# %%
print(len(data['response']['items'])) # Выводим на экран количество элементов словаря
# Out:
# 1000

# %% [markdown]
# Мы видим, что всего пользователей в группе больше 11 миллионов, а получили мы только первую тысячу пользователей группы. По информации, указанной в документации о параметре count, это максимум, который может отдать API за один раз.
#
# Для получения следующей тысячи пользователей можно воспользоваться параметром offset (с англ. смещение), который передвинет начало отсчёта. Для выгрузки всех пользователей группы будем в цикле выгружать по 1000 пользователей (count будет всегда равен 1000), увеличивая смещение offset на величину count.
#
# Для тренировки напишем цикл выгрузки первых 20 пользователей со значением count=5. Иными словами, мы будем выгружать по пять пользователей за запрос до тех пор, пока не получим информацию о 20 пользователях.
#
# Давайте выведем на экран первые 20 пользователей из нашей первой попытки получить информацию о 1000 пользователей, чтобы мы могли сверить результат выгрузки из 20 пользователей:

# %%
users_for_checking = data['response']['items'][:20] # Загружаем в переменную информацию об id первых 20 пользователей в виде списка
print(users_for_checking) # Выводим перечень id первых 20 пользователей
# Out:
# [6, 19, 47, 54, 79, 177, 198, 212, 219, 239, 243, 345, 407, 421, 450, 467, 485, 510, 550, 619]

# %% [markdown]
# Теперь используем count и offset, чтобы получить те же id по пять за раз:

# %%
import requests # Импортируем модуль requests
token = 'f478c980f478c980f478c980c6f76a3956ff478f478c980907c3d0e0c0d3721b1596fc9' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес обращения
count = 5 
offset = 0 
user_ids = [] 
max_count = 20 
while offset < max_count: 
    # Будем выгружать по count=5 пользователей, 
    # начиная с того места, где закончили на предыдущей итерации (offset) 
    print('Выгружаю {} пользователей с offset = {}'.format(count, offset))   
    params = {'group_id': 'vk', 'v': 5.95, 'count': count, 'offset': offset, 'access_token': token} 
    response = requests.get(url, params = params) 
    data = response.json() 
    user_ids += data['response']['items'] 
    # Увеличиваем смещение на количество строк, которое мы уже выгрузили 
    offset += count 
print(user_ids)
# Out:
# Выгружаю 5 пользователей с offset = 0
# Выгружаю 5 пользователей с offset = 5
# Выгружаю 5 пользователей с offset = 10
# Выгружаю 5 пользователей с offset = 15
# [6, 19, 47, 54, 79, 177, 198, 212, 219, 239, 243, 345, 407, 421, 450, 467, 485, 510, 550, 619]

# %% [markdown]
# Сравним списки, полученные двумя способами:

# %%
print(user_ids == users_for_checking)
# Out:
# True

# %% [markdown]
# Так как результат сравнения — True, списки идентичны. Значит, второй способ работает корректно. Теперь мы можем получить данные обо всех пользователях, выставив count = 1000 и max_count = data['response']['count'].
#
# ## <center>ОГРАНИЧЕНИЕ ПО ЧАСТОТЕ ЗАПРОСОВ
#
# >В API часто добавляют ограничение по частоте запросов, чтобы отдельно взятые пользователи слишком сильно не перегружали сервер. Подобное ограничение есть и у ВКонтакте — в документации указано, что можно делать не более трёх запросов в секунду.
#
# Чтобы не следить за частотой отправки запросов с секундомером в руках, мы можем после каждого запроса делать паузу. В этом случае, даже если код будет выполняться на самом быстром компьютере, мы не нарушим установленное ограничение, так как периодичность отправки запросов будет искусственно замедлена.
#
# Воспользуемся библиотекой time и методом sleep, с помощью которого мы можем добавить паузу, например в 0.5 секунд, после каждого запроса:

# %%
import requests # Импортируем модуль requests
import time # Импортируем модуль time
token = 'f478c980f478c980f478c980c6f76a3956ff478f478c980907c3d0e0c0d3721b1596fc9' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес страницы, к которой делаем запрос
count = 1000 
offset = 0  
user_ids = []  
while offset < 5000: 
    params = {'group_id': 'vk', 'v': 5.95, 'count': count, 'offset': offset, 'access_token': token} 
    response = requests.get(url, params = params) 
    data = response.json() 
    user_ids += data['response']['items'] 
    offset += count 
    print('Ожидаю 0.5 секунды...') 
    time.sleep(0.5) 
print('Цикл завершен, offset =',offset)
# Out:
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Цикл завершен, offset = 5000

# %% [markdown]
# ## <center>ЛАЙКИ, РЕПОСТЫ И КОММЕНТАРИИ
#
# Через API новостной ленты ВКонтакте мы можем получить информацию о взаимодействии с сообщениями в ленте.
#
# Для примера продолжим работать с группой https://vk.com/vk и рассмотрим последние 100 сообщений в новостной ленте.
#
# >Примечание: обратите внимание, что т.к. сообщения в новостной ленте непрерывно обновляются, то ваш результат выполнения кода ниже будет отличаться от нашего варианта.
#
# Для получения информации о сообщениях на стене в API ВКонтакте предусмотрен метод [wall.get](https://vk.com/dev/wall.get). Применим его:

# %%
import requests # Импортируем модуль requests
from pprint import pprint # Импортируем функцию pprint()
token = 'f478c980f478c980f478c980c6f76a3956ff478f478c980907c3d0e0c0d3721b1596fc9' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/wall.get' # Указываем адрес страницы, к которой делаем запрос
params = {'domain': 'vk', 'filter': 'owner', 'count': 1000, 'offset': 0, 'access_token': token, 'v': 5.95} 
response = requests.get(url, params = params) 
pprint(response.json())
# Out:
# {'response': {'count': 584,
#               'items': [{'attachments': [{'photo': {'access_key': 'd500b72845fe436562',
#                                                     'album_id': -7,
#                                                     'date': 1678189310,
#                                                     'id': 457340296,
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1390513,
#                                                     'sizes': [{'height': 50,
#                                                                'type': 's',
#                                                                'url': 'https://sun7-6.userapi.com/impg/rQtPIBQf0MaOK4_NzR5Xp0l_9yzlZvsnq98Q3Q/rNDwrw7MbPY.jpg?size=75x50&quality=95&sign=2f2d68e27c60303c750121d882e3b035&c_uniq_tag=NweolwVhPArbBZWeFOWrI-I5t_ZtvMeKS1LJA3-Xk5M&type=album',
#                                                                'width': 75},
#                                                               {'height': 87,
#                                                                'type': 'm',
#                                                                'url': 'https://sun7-6.userapi.com/impg/rQtPIBQf0MaOK4_NzR5Xp0l_9yzlZvsnq98Q3Q/rNDwrw7MbPY.jpg?size=130x87&quality=95&sign=9b53eefb478b4e317aaab30eeae179d6&c_uniq_tag=Z7z0qnnsysw8xjDwcGn4_ZRzeqeB5eGhUaZfN1UmD60&type=album',
#                                                                'width': 130},
#                                                               {'height': 402,
#                                                                'type': 'x',
#                                                                'url': 'https://sun7-6.userapi.com/impg/rQtPIBQf0MaOK4_NzR5Xp0l_9yzlZvsnq98Q3Q/rNDwrw7MbPY.jpg?size=604x402&quality=95&sign=013c560d06940c53e01eef64cfef3992&c_uniq_tag=B4NDR5Zdu-cn96G0Yt2iPt1ZeAdDQVaO044lw6q0D-I&type=album',
#                                                                'width': 604},
#                                                               {'height': 537,
#                                                                'type': 'y',
#                                                                'url': 'https://sun7-6.userapi.com/impg/rQtPIBQf0MaOK4_NzR5Xp0l_9yzlZvsnq98Q3Q/rNDwrw7MbPY.jpg?size=807x537&quality=95&sign=0b93dda8e7f72fb3482489d4a13aefac&c_uniq_tag=Qt-FurIONl-COuZ1Oltz3_TwXaXhpFG9h23HEW_FXPI&type=album',
#                                                                'width': 807},
#                                                               {'height': 852,
#                                                                'type': 'z',
#                                                                'url': 'https://sun7-6.userapi.com/impg/rQtPIBQf0MaOK4_NzR5Xp0l_9yzlZvsnq98Q3Q/rNDwrw7MbPY.jpg?size=1280x852&quality=95&sign=3750eccbd4f7201ff50c247f97535e15&c_uniq_tag=UwEnQT96NsK38plvzDkwGIkG7gatMl1bXdy6HcDf2yc&type=album',
#                                                                'width': 1280},
#                                                               {'height': 932,
#                                                                'type': 'w',
#                                                                'url': 'https://sun7-6.userapi.com/impg/rQtPIBQf0MaOK4_NzR5Xp0l_9yzlZvsnq98Q3Q/rNDwrw7MbPY.jpg?size=1400x932&quality=95&sign=a99023c2ffe2c513804bbddde594858b&c_uniq_tag=G2SuWwaPCvbOzd-SiRkg0JFRkD_83HyA1hdj7Ty3D14&type=album',
#                                                                'width': 1400},
#                                                               {'height': 87,
#                                                                'type': 'o',
#                                                                'url': 'https://sun7-6.userapi.com/impg/rQtPIBQf0MaOK4_NzR5Xp0l_9yzlZvsnq98Q3Q/rNDwrw7MbPY.jpg?size=130x87&quality=95&sign=9b53eefb478b4e317aaab30eeae179d6&c_uniq_tag=Z7z0qnnsysw8xjDwcGn4_ZRzeqeB5eGhUaZfN1UmD60&type=album',
#                                                                'width': 130},
#                                                               {'height': 133,
#                                                                'type': 'p',
#                                                                'url': 'https://sun7-6.userapi.com/impg/rQtPIBQf0MaOK4_NzR5Xp0l_9yzlZvsnq98Q3Q/rNDwrw7MbPY.jpg?size=200x133&quality=95&sign=28fe4a849e68fc8f4e4b63fb120987d8&c_uniq_tag=3xgFhbjS3sQwWY-YIdk7uZgcjB3aZ9hihdGr8k2xuxM&type=album',
#                                                                'width': 200},
#                                                               {'height': 213,
#                                                                'type': 'q',
#                                                                'url': 'https://sun7-6.userapi.com/impg/rQtPIBQf0MaOK4_NzR5Xp0l_9yzlZvsnq98Q3Q/rNDwrw7MbPY.jpg?size=320x213&quality=95&sign=0fe3e2e4d74bb2e96387f340488e6859&c_uniq_tag=DDuRJRezLr9gqirnUO-1WvTbEzXuowi2HcpLlvsEsQ8&type=album',
#                                                                'width': 320},
#                                                               {'height': 340,
#                                                                'type': 'r',
#                                                                'url': 'https://sun7-6.userapi.com/impg/rQtPIBQf0MaOK4_NzR5Xp0l_9yzlZvsnq98Q3Q/rNDwrw7MbPY.jpg?size=510x340&quality=95&sign=d28cfa3e9591b259efa2300086a057da&c_uniq_tag=aeDs6lwzys8PilrizBe6WpOnqDj1REX5At0MHU_sPpc&type=album',
#                                                                'width': 510}],
#                                                     'text': '',
#                                                     'user_id': 100},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 150,
#                                       'groups_can_post': True},
#                          'date': 1678260600,
#                          'from_id': -22822305,
#                          'hash': 'U8w9D9IA7840a5SB6g',
#                          'id': 1390513,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 1041,
#                                    'repost_disabled': False,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 78, 'user_reposted': 0},
#                          'text': 'К 8 Марта сотрудницы ВКонтакте поделились '
#                                  'своими историями — о пути в IT, мечтах '
#                                  'изменить мир и борьбе с предрассудками и '
#                                  'стереотипами. Читайте вдохновляющую статью '
#                                  'на VC: vk.cc/cm64OM.',
#                          'type': 'post',
#                          'views': {'count': 811370}},
#                         {'attachments': [{'photo': {'access_key': '10c637d673f273ffa6',
#                                                     'album_id': -7,
#                                                     'date': 1678102444,
#                                                     'id': 457340228,
#                                                     'owner_id': -22822305,
#                                                     'sizes': [{'height': 42,
#                                                                'type': 's',
#                                                                'url': 'https://sun7-15.userapi.com/impg/t1PPKvFVdYgOR-xbmuswAY3DerVClwxcWe54wQ/1jLdzPjqd88.jpg?size=75x42&quality=95&sign=f5aa7b21d3ef048bd8720ef73256e335&c_uniq_tag=iiic7A-nZ2rL_60TLB84QJGcBLh7_EpBr8_zcARxXwc&type=album',
#                                                                'width': 75},
#                                                               {'height': 73,
#                                                                'type': 'm',
#                                                                'url': 'https://sun7-15.userapi.com/impg/t1PPKvFVdYgOR-xbmuswAY3DerVClwxcWe54wQ/1jLdzPjqd88.jpg?size=130x73&quality=95&sign=4720170ece53151eb079368a6b033a4d&c_uniq_tag=yiSWczhXxD8Ux5ZNPi90pQlbP3pX1GL5j_IGiD9xDAk&type=album',
#                                                                'width': 130},
#                                                               {'height': 340,
#                                                                'type': 'x',
#                                                                'url': 'https://sun7-15.userapi.com/impg/t1PPKvFVdYgOR-xbmuswAY3DerVClwxcWe54wQ/1jLdzPjqd88.jpg?size=604x340&quality=95&sign=e6a12562085dd6dd1789dcc56c281c6c&c_uniq_tag=iFOHc0PYSajiHGbMuigTJpcyks_EGfPFOV2ZX148p-I&type=album',
#                                                                'width': 604},
#                                                               {'height': 454,
#                                                                'type': 'y',
#                                                                'url': 'https://sun7-15.userapi.com/impg/t1PPKvFVdYgOR-xbmuswAY3DerVClwxcWe54wQ/1jLdzPjqd88.jpg?size=807x454&quality=95&sign=71c4b1f756da0d4e0fca937f585dffee&c_uniq_tag=PiwEk35UwvhbFP_Bd8KKDKmGneRH7_apIMCFz9dOc90&type=album',
#                                                                'width': 807},
#                                                               {'height': 720,
#                                                                'type': 'z',
#                                                                'url': 'https://sun7-15.userapi.com/impg/t1PPKvFVdYgOR-xbmuswAY3DerVClwxcWe54wQ/1jLdzPjqd88.jpg?size=1280x720&quality=95&sign=d248b9e172ec0442ada4061c8b454964&c_uniq_tag=f6dkg0FeTE5QJVLsQq_schoML3jpOHuaqJJmLddKEu4&type=album',
#                                                                'width': 1280},
#                                                               {'height': 87,
#                                                                'type': 'o',
#                                                                'url': 'https://sun7-15.userapi.com/impg/t1PPKvFVdYgOR-xbmuswAY3DerVClwxcWe54wQ/1jLdzPjqd88.jpg?size=130x87&quality=95&crop=102,0,1076,720&sign=6eddced043bbcc56adeb903f7028d40f&c_uniq_tag=gX2DMspGtZjNWaCK1zM6ZPEwKnZTsPdCvbqISt4ovYc&type=album',
#                                                                'width': 130},
#                                                               {'height': 133,
#                                                                'type': 'p',
#                                                                'url': 'https://sun7-15.userapi.com/impg/t1PPKvFVdYgOR-xbmuswAY3DerVClwxcWe54wQ/1jLdzPjqd88.jpg?size=200x133&quality=95&crop=98,0,1083,720&sign=5673036cbfe7505c98442560e42ed64a&c_uniq_tag=_XHtUl5IVSvnxRufgMWPcmX3GyguerdO0AidFewu4oY&type=album',
#                                                                'width': 200},
#                                                               {'height': 213,
#                                                                'type': 'q',
#                                                                'url': 'https://sun7-15.userapi.com/impg/t1PPKvFVdYgOR-xbmuswAY3DerVClwxcWe54wQ/1jLdzPjqd88.jpg?size=320x213&quality=95&crop=99,0,1082,720&sign=17d1e40c8ccb1ba08f5dd76e087fbd01&c_uniq_tag=pBEoN9684rDBE-ULDhJhzW65FYKJ3laT5tKYkHaPnZs&type=album',
#                                                                'width': 320},
#                                                               {'height': 340,
#                                                                'type': 'r',
#                                                                'url': 'https://sun7-15.userapi.com/impg/t1PPKvFVdYgOR-xbmuswAY3DerVClwxcWe54wQ/1jLdzPjqd88.jpg?size=510x340&quality=95&crop=100,0,1080,720&sign=1e71a0af8fe5b245c110b494c0a52e14&c_uniq_tag=vIEZ8miEXobt0dEEOyJIcsnHudF8JHtGmMD07EXn1z8&type=album',
#                                                                'width': 510}],
#                                                     'text': '',
#                                                     'user_id': 100},
#                                           'type': 'photo'},
#                                          {'link': {'description': 'В начале '
#                                                                   '2023 года '
#                                                                   'мы '
#                                                                   'запустили '
#                                                                   'VK '
#                                                                   'Мессенджер '
#                                                                   'для '
#                                                                   'компьютера, '
#                                                                   'открыли '
#                                                                   'раздел с '
#                                                                   'подкастами '
#                                                                   'в VK '
#                                                                   'Музыке, '
#                                                                   'сделали '
#                                                                   'первую '
#                                                                   'партнёрскую '
#                                                                   'механику '
#                                                                   'для выпуска '
#                                                                   'NFT-коллекций '
#                                                                   '— и не '
#                                                                   'только. '
#                                                                   'Собрали '
#                                                                   'самые '
#                                                                   'заметные '
#                                                                   'новинки в '
#                                                                   'дайджесте․',
#                                                    'photo': {'album_id': -27,
#                                                              'date': 1678203316,
#                                                              'id': 457419851,
#                                                              'owner_id': 2000037585,
#                                                              'sizes': [{'height': 594,
#                                                                         'type': 'temp',
#                                                                         'url': 'https://sun7-14.userapi.com/cqQl70vOrcQInbPwOfXyzbu7yXqgv2lw9pVdqA/UaSbllfkNDU.jpg',
#                                                                         'width': 1074},
#                                                                        {'height': 35,
#                                                                         'type': 's',
#                                                                         'url': 'https://sun7-16.userapi.com/impg/Nmc4fxdw5zThHV98Wl6PuEhhD6F9IAjBFB6a6A/dceDpO7eYV4.jpg?size=75x35&quality=96&crop=22,0,1029,480&sign=98f3ad3d7c6852ea2f10fdd5c0e9831a&c_uniq_tag=oscgv-egYFfHZB-vHneAwJRTP60ihbQ9VfDibYxBpDQ&type=share',
#                                                                         'width': 75},
#                                                                        {'height': 80,
#                                                                         'type': 'm',
#                                                                         'url': 'https://sun7-16.userapi.com/impg/Nmc4fxdw5zThHV98Wl6PuEhhD6F9IAjBFB6a6A/dceDpO7eYV4.jpg?size=130x80&quality=96&crop=147,0,780,480&sign=f9aa83d4249a08a2db3391c128d42782&c_uniq_tag=wurEdb3dAIcB_BHAfzDnJs-R1tzBfwzwzO60RaBTIm8&type=share',
#                                                                         'width': 130},
#                                                                        {'height': 80,
#                                                                         'type': 'x',
#                                                                         'url': 'https://sun7-16.userapi.com/impg/Nmc4fxdw5zThHV98Wl6PuEhhD6F9IAjBFB6a6A/dceDpO7eYV4.jpg?size=150x80&quality=96&crop=87,0,900,480&sign=9bb54e2bba56d98f34a93152d23a5d0a&c_uniq_tag=W3stlrpVtKXf2etqE8AD2dS16js5KI9xaDrh_AvHBb8&type=share',
#                                                                         'width': 150},
#                                                                        {'height': 140,
#                                                                         'type': 'p',
#                                                                         'url': 'https://sun7-16.userapi.com/impg/Nmc4fxdw5zThHV98Wl6PuEhhD6F9IAjBFB6a6A/dceDpO7eYV4.jpg?size=260x140&quality=96&crop=91,0,891,480&sign=86a3d7ca0c254a852eaa2dbb747cac39&c_uniq_tag=vV1H_tHpkYo9ZfidHgmR3AWhoS2yaXv1_UYhBG7zQbs&type=share',
#                                                                         'width': 260},
#                                                                        {'height': 240,
#                                                                         'type': 'l',
#                                                                         'url': 'https://sun7-16.userapi.com/impg/Nmc4fxdw5zThHV98Wl6PuEhhD6F9IAjBFB6a6A/dceDpO7eYV4.jpg?size=537x240&quality=96&sign=0c5e8715f178a98750c37bb1f1c18acc&c_uniq_tag=X7O6x2k0jQwV2I9JzIdOLYSMU2I5KE_OZPknysjGIN0&type=share',
#                                                                         'width': 537},
#                                                                        {'height': 480,
#                                                                         'type': 'k',
#                                                                         'url': 'https://sun7-16.userapi.com/impg/Nmc4fxdw5zThHV98Wl6PuEhhD6F9IAjBFB6a6A/dceDpO7eYV4.jpg?size=1074x480&quality=96&sign=a5329a110823d5acc42b8155b4aaf5ad&c_uniq_tag=-2l865UFuN3nDZXZjySYd48nlwZInHykdowIGf4cJuo&type=share',
#                                                                         'width': 1074}],
#                                                              'text': '',
#                                                              'user_id': 100},
#                                                    'target': 'internal',
#                                                    'title': 'Дайджест '
#                                                             'обновлений: '
#                                                             'январь — февраль '
#                                                             '2023',
#                                                    'url': 'https://vk.com/blog/daydzhest-obnovleniy-january-febrary'},
#                                           'type': 'link'}],
#                          'comments': {'can_post': 1,
#                                       'count': 130,
#                                       'groups_can_post': True},
#                          'date': 1678203000,
#                          'edited': 1678203316,
#                          'from_id': -22822305,
#                          'hash': 'wdNlxgfCGU8c4LlngA',
#                          'id': 1390268,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 386,
#                                    'repost_disabled': False,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 41, 'user_reposted': 0},
#                          'text': 'В начале 2023 года мы запустили VK '
#                                  'Мессенджер для компьютера, открыли раздел с '
#                                  'подкастами в VK Музыке, сделали первую '
#                                  'партнёрскую механику для выпуска '
#                                  'NFT-коллекций — и не только. Собрали самые '
#                                  'заметные новинки в '
#                                  '[vk.com/blog/daydzhest-obnovleniy-january-febrary|дайджесте].',
#                          'type': 'post',
#                          'views': {'count': 214550}},
#                         {'attachments': [{'photo': {'access_key': '9d6648bcd102f81a09',
#                                                     'album_id': -7,
#                                                     'date': 1678169873,
#                                                     'id': 457340290,
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1390206,
#                                                     'sizes': [{'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun7-8.userapi.com/impg/jGgDCFki53x2A0-MZWMz4R7UlFTS_d1seq1G6A/VrR4Xh3oE-k.jpg?size=75x75&quality=95&sign=aa8bc44e756d0240a86eeea0c706d51e&c_uniq_tag=8q7i-kFISV5OIGw4Zw2qROh3ajy4-FdZfe1YIayrsH4&type=album',
#                                                                'width': 75},
#                                                               {'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun7-8.userapi.com/impg/jGgDCFki53x2A0-MZWMz4R7UlFTS_d1seq1G6A/VrR4Xh3oE-k.jpg?size=130x130&quality=95&sign=25c0106fb51cb787d4418c8ed684ef90&c_uniq_tag=hMxkzsaSUUqbXGEODEMmrvJ4VPODzaNFEMluUH2ORzs&type=album',
#                                                                'width': 130},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun7-8.userapi.com/impg/jGgDCFki53x2A0-MZWMz4R7UlFTS_d1seq1G6A/VrR4Xh3oE-k.jpg?size=604x604&quality=95&sign=0bf2d0460f9eabbb59717085b1770ea8&c_uniq_tag=18fVMozp2dLjTrARwZ6WqTjsfO_aD-ZFJYSYbOQ94sc&type=album',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun7-8.userapi.com/impg/jGgDCFki53x2A0-MZWMz4R7UlFTS_d1seq1G6A/VrR4Xh3oE-k.jpg?size=807x807&quality=95&sign=95bcbeb07a82ab50e078fa57a993a95e&c_uniq_tag=aB8SI5XwPDBHsm2ctl65UNIVZX-iB2qqk1xPBHtaczw&type=album',
#                                                                'width': 807},
#                                                               {'height': 1200,
#                                                                'type': 'z',
#                                                                'url': 'https://sun7-8.userapi.com/impg/jGgDCFki53x2A0-MZWMz4R7UlFTS_d1seq1G6A/VrR4Xh3oE-k.jpg?size=1200x1200&quality=95&sign=abcad5baec4db1298ffe8f6c7838cf8d&c_uniq_tag=F4-GlSdT8szWmHf8xKqim3S9c5-BQ3KLoxU9nlKvkgI&type=album',
#                                                                'width': 1200},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun7-8.userapi.com/impg/jGgDCFki53x2A0-MZWMz4R7UlFTS_d1seq1G6A/VrR4Xh3oE-k.jpg?size=130x130&quality=95&sign=25c0106fb51cb787d4418c8ed684ef90&c_uniq_tag=hMxkzsaSUUqbXGEODEMmrvJ4VPODzaNFEMluUH2ORzs&type=album',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun7-8.userapi.com/impg/jGgDCFki53x2A0-MZWMz4R7UlFTS_d1seq1G6A/VrR4Xh3oE-k.jpg?size=200x200&quality=95&sign=f740d4d54c7420b3b15a393fccc831f2&c_uniq_tag=_njaHZt01nBTzim0S_kemHKyToNUnKe9yT5zqxPlpPo&type=album',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun7-8.userapi.com/impg/jGgDCFki53x2A0-MZWMz4R7UlFTS_d1seq1G6A/VrR4Xh3oE-k.jpg?size=320x320&quality=95&sign=f0e6cafe0f2eb1605311c9f6e69109c5&c_uniq_tag=QROYcYsnELsxek6LXST2sxCG-iQoL1JBrBh_hAZHVyo&type=album',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun7-8.userapi.com/impg/jGgDCFki53x2A0-MZWMz4R7UlFTS_d1seq1G6A/VrR4Xh3oE-k.jpg?size=510x510&quality=95&sign=2e13f2e18afb0e73ba6771bd59ccac15&c_uniq_tag=QkQohAjKmO3ajKVmAv08ofArhVq0oEKwjGwSQ2PPTg0&type=album',
#                                                                'width': 510}],
#                                                     'text': '',
#                                                     'user_id': 100},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 89,
#                                       'groups_can_post': True},
#                          'date': 1678192985,
#                          'from_id': -22822305,
#                          'hash': 'zk_qYt7-PgG3MYcnkQ',
#                          'id': 1390206,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 471,
#                                    'repost_disabled': False,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 70, 'user_reposted': 0},
#                          'text': 'Мы посвятим 3D-инсталляцию выдающимся '
#                                  'женщинам, а вы — определите, кому именно. '
#                                  'Представляем проект «Женских рук дело».\n'
#                                  '\n'
#                                  'Откройте сервис '
#                                  '[https://vk.com/app51560653|«О женщинах»] и '
#                                  'изучите карточки с описанием достижений. Кто '
#                                  'станет героиней первой голографической '
#                                  'экспозиции, решать вам. До 27 марта можете '
#                                  'ежедневно голосовать за трёх женщин из '
#                                  'списка. Это также даст вам доступ к '
#                                  'эмодзи-статусам проекта. \n'
#                                  '\n'
#                                  'В России всего несколько десятков памятников '
#                                  'посвящены женщинам — вместе с вами мы '
#                                  'изменим это соотношение. '
#                                  'Диджитал-инсталляцию можно будет увидеть как '
#                                  'в сервисе, так и в реальности — в творческих '
#                                  'и общественных пространствах. А в скором '
#                                  'времени мы запустим и NFT-коллекцию с '
#                                  'изображениями выдающихся женщин.',
#                          'type': 'post',
#                          'views': {'count': 236003}},
#                         {'attachments': [{'photo': {'access_key': '237d9f83ff70d0d4d4',
#                                                     'album_id': -7,
#                                                     'date': 1677740416,
#                                                     'id': 457340017,
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1388800,
#                                                     'sizes': [{'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun7-14.userapi.com/impg/84G05SjkYsNfkKXrvIshsuJT8vlci8MH2ugbHw/S3mug_Jic9c.jpg?size=75x75&quality=95&sign=fc578c733592a0aaf8dbc75081039cc9&c_uniq_tag=uIEiocO-YhcBI2HTEcv2HbZleTBKmO4NaVPRyfWP2E8&type=album',
#                                                                'width': 75},
#                                                               {'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun7-14.userapi.com/impg/84G05SjkYsNfkKXrvIshsuJT8vlci8MH2ugbHw/S3mug_Jic9c.jpg?size=130x130&quality=95&sign=c9fcacf54bc662181ce50441418738d1&c_uniq_tag=RKDs73pq85OUn14CUVhvbwJxL8T-hXs7ArPWdMKRgvk&type=album',
#                                                                'width': 130},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun7-14.userapi.com/impg/84G05SjkYsNfkKXrvIshsuJT8vlci8MH2ugbHw/S3mug_Jic9c.jpg?size=604x604&quality=95&sign=74d71fd7dbf4c07b012a4666f07b678c&c_uniq_tag=-qs_vUO7N62k_E8i6MJfnqntykR5nsEGVIngaIsEV1g&type=album',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun7-14.userapi.com/impg/84G05SjkYsNfkKXrvIshsuJT8vlci8MH2ugbHw/S3mug_Jic9c.jpg?size=807x807&quality=95&sign=a24749cf4f606596fa86cfc140ee3a06&c_uniq_tag=-doMOHkEuh1g-FDlonB8k5rspJhdRh7ouWSmdWeQ03o&type=album',
#                                                                'width': 807},
#                                                               {'height': 1280,
#                                                                'type': 'z',
#                                                                'url': 'https://sun7-14.userapi.com/impg/84G05SjkYsNfkKXrvIshsuJT8vlci8MH2ugbHw/S3mug_Jic9c.jpg?size=1280x1280&quality=95&sign=7d6711ec08010ed155df127d8e0c1c91&c_uniq_tag=3giTMiivSzeyQ__YWv2Ux7PwaJ-lMDk_fbqceoUHSeo&type=album',
#                                                                'width': 1280},
#                                                               {'height': 1500,
#                                                                'type': 'w',
#                                                                'url': 'https://sun7-14.userapi.com/impg/84G05SjkYsNfkKXrvIshsuJT8vlci8MH2ugbHw/S3mug_Jic9c.jpg?size=1500x1500&quality=95&sign=034f2a1fc117ed51d9c85bd489a4149b&c_uniq_tag=cKRhpFWMIYUiM_2f90tbvKfdfl4FhNkP7cVpxieaO8E&type=album',
#                                                                'width': 1500},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun7-14.userapi.com/impg/84G05SjkYsNfkKXrvIshsuJT8vlci8MH2ugbHw/S3mug_Jic9c.jpg?size=130x130&quality=95&sign=c9fcacf54bc662181ce50441418738d1&c_uniq_tag=RKDs73pq85OUn14CUVhvbwJxL8T-hXs7ArPWdMKRgvk&type=album',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun7-14.userapi.com/impg/84G05SjkYsNfkKXrvIshsuJT8vlci8MH2ugbHw/S3mug_Jic9c.jpg?size=200x200&quality=95&sign=c536b3df0dbfea13c85584a47c0d20df&c_uniq_tag=dUpX5Q74oO-mk4y6Q-B85QvNoFUbPCK9a5YUPvxHhcs&type=album',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun7-14.userapi.com/impg/84G05SjkYsNfkKXrvIshsuJT8vlci8MH2ugbHw/S3mug_Jic9c.jpg?size=320x320&quality=95&sign=7ac317258a735bc7a5b408fdc09fe448&c_uniq_tag=E_nvmM5fDm3uFlAxfZMQ_wEaKn45ns5P97WgLO7BT48&type=album',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun7-14.userapi.com/impg/84G05SjkYsNfkKXrvIshsuJT8vlci8MH2ugbHw/S3mug_Jic9c.jpg?size=510x510&quality=95&sign=9676f0e1c2afb6d6662954c199339889&c_uniq_tag=KiBKz5-F1UaG8HAb3J3KCz37LRqxHdirJnLbZnoAP_M&type=album',
#                                                                'width': 510}],
#                                                     'text': '',
#                                                     'user_id': 100},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 684,
#                                       'groups_can_post': True},
#                          'date': 1677758960,
#                          'from_id': -22822305,
#                          'hash': 'gpE_IStKA0c8I6vXww',
#                          'id': 1388800,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 896,
#                                    'repost_disabled': False,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 354, 'user_reposted': 0},
#                          'text': 'Сделайте свой профиль ещё красочнее с '
#                                  'обложками от нейросети. Искусственный '
#                                  'интеллект учитывает увлечения и подписки — и '
#                                  'на основе этого предлагает шесть вариантов '
#                                  'самых подходящих артов. \n'
#                                  '\n'
#                                  'Доступны разные темы и персональные стили: '
#                                  'от киберпанка и футуризма до пиццы и '
#                                  'футбола. Обложку уже можно установить в '
#                                  'специальном сервисе: vk.com/app51427113.',
#                          'type': 'post',
#                          'views': {'count': 412732}},
#                         {'attachments': [{'photo': {'access_key': 'dfbaf7e29d012970e1',
#                                                     'album_id': -7,
#                                                     'date': 1677740527,
#                                                     'id': 457340018,
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1388682,
#                                                     'sizes': [{'height': 70,
#                                                                'type': 's',
#                                                                'url': 'https://sun7-16.userapi.com/impg/qe1PWTQZAW7FpXDkNXpeswVQA_jR8BTNdl-XlA/stI9yMCVeJE.jpg?size=75x70&quality=95&sign=1a6d1c8ee50d5184559d0baca3459e05&c_uniq_tag=qfdN0MhhT3dTitQxw_t1weBRJE2j94T2vtSd8DdDzTM&type=album',
#                                                                'width': 75},
#                                                               {'height': 122,
#                                                                'type': 'm',
#                                                                'url': 'https://sun7-16.userapi.com/impg/qe1PWTQZAW7FpXDkNXpeswVQA_jR8BTNdl-XlA/stI9yMCVeJE.jpg?size=130x122&quality=95&sign=20f50483ee1b662bfb970a061256f7a9&c_uniq_tag=1k9OoMDQTJN-JUslKQjLPsL-0y6KHhrLKbcJ3C-30Ts&type=album',
#                                                                'width': 130},
#                                                               {'height': 567,
#                                                                'type': 'x',
#                                                                'url': 'https://sun7-16.userapi.com/impg/qe1PWTQZAW7FpXDkNXpeswVQA_jR8BTNdl-XlA/stI9yMCVeJE.jpg?size=604x567&quality=95&sign=99d3868ba56c9e59669cd0d75f66005e&c_uniq_tag=rRh3C3G7dOy0vjir-YbYNY-dqgGSFFdonEQZH7n9hPA&type=album',
#                                                                'width': 604},
#                                                               {'height': 758,
#                                                                'type': 'y',
#                                                                'url': 'https://sun7-16.userapi.com/impg/qe1PWTQZAW7FpXDkNXpeswVQA_jR8BTNdl-XlA/stI9yMCVeJE.jpg?size=807x758&quality=95&sign=fcb6b2538dfc55de0e55edb858c52876&c_uniq_tag=9fBhJkkev1QZzY7yQLrUKJrt7Sa1i5XJtKeigNbuM4c&type=album',
#                                                                'width': 807},
#                                                               {'height': 1202,
#                                                                'type': 'z',
#                                                                'url': 'https://sun7-16.userapi.com/impg/qe1PWTQZAW7FpXDkNXpeswVQA_jR8BTNdl-XlA/stI9yMCVeJE.jpg?size=1280x1202&quality=95&sign=ab6c68cc6df15fa59e418bdaef6bae06&c_uniq_tag=tLjn9_WSTt9veCwF27PTX2HutLcEfiTMif9b0xanB9o&type=album',
#                                                                'width': 1280},
#                                                               {'height': 2160,
#                                                                'type': 'w',
#                                                                'url': 'https://sun7-16.userapi.com/impg/qe1PWTQZAW7FpXDkNXpeswVQA_jR8BTNdl-XlA/stI9yMCVeJE.jpg?size=2300x2160&quality=95&sign=5a8e2a7dd02c1ed617d60c0f09d02d50&c_uniq_tag=YkYypQKypZSsicS6gCPzsawCFsXf4DI6bDC8YadY_cw&type=album',
#                                                                'width': 2300},
#                                                               {'height': 122,
#                                                                'type': 'o',
#                                                                'url': 'https://sun7-16.userapi.com/impg/qe1PWTQZAW7FpXDkNXpeswVQA_jR8BTNdl-XlA/stI9yMCVeJE.jpg?size=130x122&quality=95&sign=20f50483ee1b662bfb970a061256f7a9&c_uniq_tag=1k9OoMDQTJN-JUslKQjLPsL-0y6KHhrLKbcJ3C-30Ts&type=album',
#                                                                'width': 130},
#                                                               {'height': 188,
#                                                                'type': 'p',
#                                                                'url': 'https://sun7-16.userapi.com/impg/qe1PWTQZAW7FpXDkNXpeswVQA_jR8BTNdl-XlA/stI9yMCVeJE.jpg?size=200x188&quality=95&sign=0441cfd189936aa1d1c3768f9d955591&c_uniq_tag=PYzm2fSLhIEpjVbfvYCxyfdNkew2wsHe67igTyPIyeU&type=album',
#                                                                'width': 200},
#                                                               {'height': 301,
#                                                                'type': 'q',
#                                                                'url': 'https://sun7-16.userapi.com/impg/qe1PWTQZAW7FpXDkNXpeswVQA_jR8BTNdl-XlA/stI9yMCVeJE.jpg?size=320x301&quality=95&sign=3dc47bd08cdcd50a9b2bc090292105ff&c_uniq_tag=veqJRQwBGqvTUIN0bunSfRUECDvIm5j7UUrHjgAf8BI&type=album',
#                                                                'width': 320},
#                                                               {'height': 479,
#                                                                'type': 'r',
#                                                                'url': 'https://sun7-16.userapi.com/impg/qe1PWTQZAW7FpXDkNXpeswVQA_jR8BTNdl-XlA/stI9yMCVeJE.jpg?size=510x479&quality=95&sign=04f6bf4629e5268af23b485c97969557&c_uniq_tag=nIG9wDxqRYlxOdGxWEvYTAcF5xdUPWuikISJ8Ey4iZY&type=album',
#                                                                'width': 510}],
#                                                     'text': '',
#                                                     'user_id': 100},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 194,
#                                       'groups_can_post': True},
#                          'date': 1677749544,
#                          'from_id': -22822305,
#                          'hash': '2niNltOBCqINiwjVrw',
#                          'id': 1388682,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 1602,
#                                    'repost_disabled': False,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 1014, 'user_reposted': 0},
#                          'text': 'Общаемся интерактивнее: в VK Мессенджере '
#                                  'появились сервисы для совместного '
#                                  'использования.\n'
#                                  '\n'
#                                  'Вы сможете играть прямо в чате, вместе '
#                                  'выбирать покупки или рассчитывать бюджет на '
#                                  'месяц. Чтобы обсудить важное, не придётся '
#                                  'делать скриншоты и даже открывать другую '
#                                  'вкладку. Сервисы можно отправлять '
#                                  'собеседникам в мессенджере — они '
#                                  'прикрепляются к сообщению так же, как фото, '
#                                  'видео и другие вложения.\n'
#                                  '\n'
#                                  'Выполняйте задания из «Печеньки с '
#                                  'предсказаниями» или решайте спорные вопросы '
#                                  'в игре «Камень, ножницы, бумага». На старте '
#                                  'доступны развлекательные мини-приложения, а '
#                                  'вскоре добавятся сервисы для работы и '
#                                  'учёбы.\n'
#                                  '\n'
#                                  'Новинка платформы VK Mini Apps доступна в '
#                                  'чатах приложения ВКонтакте, в мобильной и '
#                                  'веб-версии. Пробуйте новый формат общения!',
#                          'type': 'post',
#                          'views': {'count': 751598}},
#                         {'attachments': [{'photo': {'access_key': '9733a3dc6da367959b',
#                                                     'album_id': -7,
#                                                     'date': 1677579220,
#                                                     'id': 457339920,
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1387886,
#                                                     'sizes': [{'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun7-7.userapi.com/impg/w7gIMjG3FTx7kBZbD3frqn23gXwrztMzyM-JsA/f3K4dWvC2HY.jpg?size=75x75&quality=95&sign=44310e54ac214c9b799ebafd4ba80ba8&c_uniq_tag=41LUPzMZZtda6qy-BTM6juGyk-YKCKTE23at0xQ4HDQ&type=album',
#                                                                'width': 75},
#                                                               {'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun7-7.userapi.com/impg/w7gIMjG3FTx7kBZbD3frqn23gXwrztMzyM-JsA/f3K4dWvC2HY.jpg?size=130x130&quality=95&sign=83da58ca61ab60eade69939fb35c6e7e&c_uniq_tag=cAw40_-Q440ImC0QReuD-C5zBWFHVOgWd8gSgZUEmos&type=album',
#                                                                'width': 130},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun7-7.userapi.com/impg/w7gIMjG3FTx7kBZbD3frqn23gXwrztMzyM-JsA/f3K4dWvC2HY.jpg?size=604x604&quality=95&sign=9f1fdc60f78ef6c23d95fdc1b4f536b1&c_uniq_tag=04zpiEWYC1JQ0z1UKard-_QqSbMyUys7TrwBTwU3IEc&type=album',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun7-7.userapi.com/impg/w7gIMjG3FTx7kBZbD3frqn23gXwrztMzyM-JsA/f3K4dWvC2HY.jpg?size=807x807&quality=95&sign=e5e8021db24d63dddda4f1f762ac9c1c&c_uniq_tag=yY7PulJbTkSrzpgabWoUoAgY7OwY6J_apiRWN5noK7Q&type=album',
#                                                                'width': 807},
#                                                               {'height': 1280,
#                                                                'type': 'z',
#                                                                'url': 'https://sun7-7.userapi.com/impg/w7gIMjG3FTx7kBZbD3frqn23gXwrztMzyM-JsA/f3K4dWvC2HY.jpg?size=1280x1280&quality=95&sign=c76efba6731ea74b4b1483c0d1fd206e&c_uniq_tag=TyDrY7-Mdyqpf1rOTKquDFSGsXnXT2w9k9djNtg_FYw&type=album',
#                                                                'width': 1280},
#                                                               {'height': 2000,
#                                                                'type': 'w',
# ...
#                                                                'width': 75},
#                                                               {'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun7-13.userapi.com/impg/xVN0JRPfNaDUkWdnGKOD0EwEnLh9mSKibpWf4A/9Sj13JIZMmk.jpg?size=130x130&quality=95&sign=a1aceb19e45e739ea1ff29cd85b45487&c_uniq_tag=e5ZxdRtLSMrbyzoNh4q2hblmGD_S8lmFzgFinRLjKUs&type=album',
#                                                                'width': 130},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun7-13.userapi.com/impg/xVN0JRPfNaDUkWdnGKOD0EwEnLh9mSKibpWf4A/9Sj13JIZMmk.jpg?size=604x604&quality=95&sign=429b40b9cba65472b1fd519409bf6ffd&c_uniq_tag=GdesdDvKZpzu6ieS5BiCKpjvLVzQaogfFhsFuegA-qY&type=album',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun7-13.userapi.com/impg/xVN0JRPfNaDUkWdnGKOD0EwEnLh9mSKibpWf4A/9Sj13JIZMmk.jpg?size=807x807&quality=95&sign=303574bb80e69932dc3c93704e1f71c6&c_uniq_tag=9gqdxKpT5XJ6crgbLm5vkD1l94FAmquK7O0slvRviPs&type=album',
#                                                                'width': 807},
#                                                               {'height': 1280,
#                                                                'type': 'z',
#                                                                'url': 'https://sun7-13.userapi.com/impg/xVN0JRPfNaDUkWdnGKOD0EwEnLh9mSKibpWf4A/9Sj13JIZMmk.jpg?size=1280x1280&quality=95&sign=3aa6d478ca56a9029fc034d963236d47&c_uniq_tag=_Bw1NFK9d08u1Gi1eNwdqqoBHf2WvJ72bSsveBAiV30&type=album',
#                                                                'width': 1280},
#                                                               {'height': 1500,
#                                                                'type': 'w',
#                                                                'url': 'https://sun7-13.userapi.com/impg/xVN0JRPfNaDUkWdnGKOD0EwEnLh9mSKibpWf4A/9Sj13JIZMmk.jpg?size=1500x1500&quality=95&sign=c8d964f2c5c1cfcc519480ae60148d3a&c_uniq_tag=wTPhtDj9f3OySAt_ow0fLHtqG05vt_BZFp20OuIyHJU&type=album',
#                                                                'width': 1500},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun7-13.userapi.com/impg/xVN0JRPfNaDUkWdnGKOD0EwEnLh9mSKibpWf4A/9Sj13JIZMmk.jpg?size=130x130&quality=95&sign=a1aceb19e45e739ea1ff29cd85b45487&c_uniq_tag=e5ZxdRtLSMrbyzoNh4q2hblmGD_S8lmFzgFinRLjKUs&type=album',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun7-13.userapi.com/impg/xVN0JRPfNaDUkWdnGKOD0EwEnLh9mSKibpWf4A/9Sj13JIZMmk.jpg?size=200x200&quality=95&sign=e5c6a93b57cbf742a0377f2ae3838a8b&c_uniq_tag=rdmzLberjsj_QSxXlcyHyFcnY5FzWiz8TjdFtauhAXo&type=album',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun7-13.userapi.com/impg/xVN0JRPfNaDUkWdnGKOD0EwEnLh9mSKibpWf4A/9Sj13JIZMmk.jpg?size=320x320&quality=95&sign=560cc4641a8a755d8e149f567c8387c0&c_uniq_tag=0py1cKyLYTKXKbSQcFiDvacp6GrN-cor9LFvRhXuhVc&type=album',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun7-13.userapi.com/impg/xVN0JRPfNaDUkWdnGKOD0EwEnLh9mSKibpWf4A/9Sj13JIZMmk.jpg?size=510x510&quality=95&sign=03f439374b3768ad217b4d08e4eeabb6&c_uniq_tag=xqH4AC_Hq-EcfJy3KNeSyLAeAzdxqHhFmWcPKJWOj1o&type=album',
#                                                                'width': 510}],
#                                                     'text': '',
#                                                     'user_id': 100},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 350,
#                                       'groups_can_post': True},
#                          'date': 1651043800,
#                          'from_id': -22822305,
#                          'hash': 'tL4evUP3SDvaTRcKkg',
#                          'id': 1296896,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 1498,
#                                    'repost_disabled': False,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 659, 'user_reposted': 0},
#                          'text': 'В конце марта мы запустили масштабную '
#                                  'программу поддержки создателей контента: её '
#                                  'участники получают максимум дохода от '
#                                  'инструментов монетизации. По первым итогам '
#                                  'средний недельный заработок сообществ на '
#                                  'маркет-платформе вырос в 1,5 раза, в '
#                                  'партнёрской программе — в 2 раза, в '
#                                  'видеомонетизации — в 4 раза, в VK Donut — на '
#                                  '40%. \n'
#                                  '\n'
#                                  'Тоже хотите монетизировать своё творчество '
#                                  'ВКонтакте? В карточках мы рассказали, как '
#                                  'заработать на платформе. Больше подробностей '
#                                  'найдёте здесь: vk.com/monetization.',
#                          'type': 'post',
#                          'views': {'count': 547467}},
#                         {'attachments': [{'photo': {'access_key': '3139673bbb504abaf3',
#                                                     'album_id': -7,
#                                                     'date': 1650904290,
#                                                     'id': 457331238,
#                                                     'owner_id': -22822305,
#                                                     'sizes': [{'height': 63,
#                                                                'type': 's',
#                                                                'url': 'https://sun7-9.userapi.com/impg/uCMVjbxmVT6SrUmWq3PWaaeeJKzmfGbTM1uxYw/8TdnDjWqFeE.jpg?size=75x63&quality=95&sign=56b0ff56d73884da21d95f9fa91855b1&c_uniq_tag=ZXiaWhbNugIF6F7gIyjZL1PRCq4dcJs6QHS6YGqCxqo&type=album',
#                                                                'width': 75},
#                                                               {'height': 109,
#                                                                'type': 'm',
#                                                                'url': 'https://sun7-9.userapi.com/impg/uCMVjbxmVT6SrUmWq3PWaaeeJKzmfGbTM1uxYw/8TdnDjWqFeE.jpg?size=130x109&quality=95&sign=0c019e5a564aaca7ec2067d6775f2ee6&c_uniq_tag=NM8n0Se1cdZeYGn-mZmSWisuVdH-TlA2sBYZmcvtZuQ&type=album',
#                                                                'width': 130},
#                                                               {'height': 507,
#                                                                'type': 'x',
#                                                                'url': 'https://sun7-9.userapi.com/impg/uCMVjbxmVT6SrUmWq3PWaaeeJKzmfGbTM1uxYw/8TdnDjWqFeE.jpg?size=604x507&quality=95&sign=96e641c41f9c234c1ba508ee8d8de253&c_uniq_tag=E9tMW5HEKUSCEPgFOVmm4et2iyJIBcoQoN5gxzPLJaQ&type=album',
#                                                                'width': 604},
#                                                               {'height': 677,
#                                                                'type': 'y',
#                                                                'url': 'https://sun7-9.userapi.com/impg/uCMVjbxmVT6SrUmWq3PWaaeeJKzmfGbTM1uxYw/8TdnDjWqFeE.jpg?size=807x677&quality=95&sign=d99c2f503596e3b548b233f900a781e8&c_uniq_tag=zzIgcje20I1yJ8Kp1xP3HltrA0G4Hb6M-aRJW3DvNiA&type=album',
#                                                                'width': 807},
#                                                               {'height': 1074,
#                                                                'type': 'z',
#                                                                'url': 'https://sun7-9.userapi.com/impg/uCMVjbxmVT6SrUmWq3PWaaeeJKzmfGbTM1uxYw/8TdnDjWqFeE.jpg?size=1280x1074&quality=95&sign=b4dfd6973590592dae529215ce50c6d8&c_uniq_tag=1iW3YbCog4YLIuOLUgnIf5NIy_GPB7tSijdXUpaKL6I&type=album',
#                                                                'width': 1280},
#                                                               {'height': 1611,
#                                                                'type': 'w',
#                                                                'url': 'https://sun7-9.userapi.com/impg/uCMVjbxmVT6SrUmWq3PWaaeeJKzmfGbTM1uxYw/8TdnDjWqFeE.jpg?size=1920x1611&quality=95&sign=4e22e4c87977cd021b5b3413873e612a&c_uniq_tag=9Z1xU6PxDJLJEaNBHk1z_WOoJlsJPvQEs9QazWLXjHI&type=album',
#                                                                'width': 1920},
#                                                               {'height': 109,
#                                                                'type': 'o',
#                                                                'url': 'https://sun7-9.userapi.com/impg/uCMVjbxmVT6SrUmWq3PWaaeeJKzmfGbTM1uxYw/8TdnDjWqFeE.jpg?size=130x109&quality=95&sign=0c019e5a564aaca7ec2067d6775f2ee6&c_uniq_tag=NM8n0Se1cdZeYGn-mZmSWisuVdH-TlA2sBYZmcvtZuQ&type=album',
#                                                                'width': 130},
#                                                               {'height': 168,
#                                                                'type': 'p',
#                                                                'url': 'https://sun7-9.userapi.com/impg/uCMVjbxmVT6SrUmWq3PWaaeeJKzmfGbTM1uxYw/8TdnDjWqFeE.jpg?size=200x168&quality=95&sign=dc291551c4677d9b17a6041818a9979a&c_uniq_tag=YLdi-KkzSD4t7blkCyvkuecBpz2nXLthbBkAaJzRLac&type=album',
#                                                                'width': 200},
#                                                               {'height': 268,
#                                                                'type': 'q',
#                                                                'url': 'https://sun7-9.userapi.com/impg/uCMVjbxmVT6SrUmWq3PWaaeeJKzmfGbTM1uxYw/8TdnDjWqFeE.jpg?size=320x268&quality=95&sign=1373cb06ae65b439a76f3cdb627a96f4&c_uniq_tag=f4D1a1aSzB36vWdXLlOEhrCd70gPCpRus5xmosZvpXQ&type=album',
#                                                                'width': 320},
#                                                               {'height': 428,
#                                                                'type': 'r',
#                                                                'url': 'https://sun7-9.userapi.com/impg/uCMVjbxmVT6SrUmWq3PWaaeeJKzmfGbTM1uxYw/8TdnDjWqFeE.jpg?size=510x428&quality=95&sign=bb6b5164312144a8ed2e78faf430ae95&c_uniq_tag=adF_bfljZ9NOJPat_iFzmgMp6pGH02ncVLe0tQgcNgs&type=album',
#                                                                'width': 510}],
#                                                     'text': '',
#                                                     'user_id': 100},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 871,
#                                       'groups_can_post': True},
#                          'date': 1650901064,
#                          'edited': 1650904290,
#                          'from_id': -22822305,
#                          'hash': 'Xj_TUobK3TeBtyBrmA',
#                          'id': 1295966,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 3583,
#                                    'repost_disabled': False,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 2103, 'user_reposted': 0},
#                          'text': 'Тёмная тема ВКонтакте теперь на всех '
#                                  'платформах! Одна из самых востребованных '
#                                  'нашими пользователями функций появилась в '
#                                  'версии ВКонтакте для компьютеров — на сайте '
#                                  'vk.com! \n'
#                                  '\n'
#                                  'Включайте, когда засиживаетесь допоздна: '
#                                  'будет комфортнее смотреть видео, листать '
#                                  'ленту или общаться в мессенджере. С '
#                                  'пониженным контрастом и тёмным фоном удобно '
#                                  'пользоваться нужными сервисами при слабой '
#                                  'освещённости — с комфортом для глаз и без '
#                                  'лишнего напряжения. А ещё это просто '
#                                  'красиво! \n'
#                                  '\n'
#                                  'Переключить тему можно в меню — за аватаром '
#                                  'в верхнем правом углу. Или просто загляните '
#                                  'на свою страницу или в профиль друга: на '
#                                  'первое время оставили там пасхалку — большой '
#                                  'переключатель, чтобы вы могли попробовать '
#                                  'новую функцию. Кроме тёмной и светлой, можно '
#                                  'выбрать системную тему: тогда ВКонтакте '
#                                  'будет затемняться вместе с вашим браузером '
#                                  'или устройством, в зависимости от расписания '
#                                  'в его настройках. \n'
#                                  '\n'
#                                  'Тёмную тему ВКонтакте можно включить на '
#                                  'любом устройстве — в мобильном приложении на '
#                                  'iOS и Android, в версии для компьютеров '
#                                  '(vk.com) и в мобильной версии (m.vk.com).',
#                          'type': 'post',
#                          'views': {'count': 657339}}]}}

# %% [markdown]
# Посмотрим на количество результатов:

# %%
len(response.json()['response']['items'])
# Out:
# 100

# %% [markdown]
# Посмотрим на информацию об отдельном сообщении:

# %%
response.json()['response']['items'][0]
# Out:
# {'comments': {'can_post': 1, 'count': 150, 'groups_can_post': True},
#  'marked_as_ads': 0,
#  'hash': 'U8w9D9IA7840a5SB6g',
#  'type': 'post',
#  'attachments': [{'type': 'photo',
#    'photo': {'album_id': -7,
#     'date': 1678189310,
#     'id': 457340296,
#     'owner_id': -22822305,
#     'access_key': 'd500b72845fe436562',
#     'post_id': 1390513,
#     'sizes': [{'height': 50,
#       'type': 's',
#       'width': 75,
#       'url': 'https://sun7-6.userapi.com/impg/rQtPIBQf0MaOK4_NzR5Xp0l_9yzlZvsnq98Q3Q/rNDwrw7MbPY.jpg?size=75x50&quality=95&sign=2f2d68e27c60303c750121d882e3b035&c_uniq_tag=NweolwVhPArbBZWeFOWrI-I5t_ZtvMeKS1LJA3-Xk5M&type=album'},
#      {'height': 87,
#       'type': 'm',
#       'width': 130,
#       'url': 'https://sun7-6.userapi.com/impg/rQtPIBQf0MaOK4_NzR5Xp0l_9yzlZvsnq98Q3Q/rNDwrw7MbPY.jpg?size=130x87&quality=95&sign=9b53eefb478b4e317aaab30eeae179d6&c_uniq_tag=Z7z0qnnsysw8xjDwcGn4_ZRzeqeB5eGhUaZfN1UmD60&type=album'},
#      {'height': 402,
#       'type': 'x',
#       'width': 604,
#       'url': 'https://sun7-6.userapi.com/impg/rQtPIBQf0MaOK4_NzR5Xp0l_9yzlZvsnq98Q3Q/rNDwrw7MbPY.jpg?size=604x402&quality=95&sign=013c560d06940c53e01eef64cfef3992&c_uniq_tag=B4NDR5Zdu-cn96G0Yt2iPt1ZeAdDQVaO044lw6q0D-I&type=album'},
#      {'height': 537,
#       'type': 'y',
#       'width': 807,
#       'url': 'https://sun7-6.userapi.com/impg/rQtPIBQf0MaOK4_NzR5Xp0l_9yzlZvsnq98Q3Q/rNDwrw7MbPY.jpg?size=807x537&quality=95&sign=0b93dda8e7f72fb3482489d4a13aefac&c_uniq_tag=Qt-FurIONl-COuZ1Oltz3_TwXaXhpFG9h23HEW_FXPI&type=album'},
#      {'height': 852,
#       'type': 'z',
#       'width': 1280,
#       'url': 'https://sun7-6.userapi.com/impg/rQtPIBQf0MaOK4_NzR5Xp0l_9yzlZvsnq98Q3Q/rNDwrw7MbPY.jpg?size=1280x852&quality=95&sign=3750eccbd4f7201ff50c247f97535e15&c_uniq_tag=UwEnQT96NsK38plvzDkwGIkG7gatMl1bXdy6HcDf2yc&type=album'},
#      {'height': 932,
#       'type': 'w',
#       'width': 1400,
#       'url': 'https://sun7-6.userapi.com/impg/rQtPIBQf0MaOK4_NzR5Xp0l_9yzlZvsnq98Q3Q/rNDwrw7MbPY.jpg?size=1400x932&quality=95&sign=a99023c2ffe2c513804bbddde594858b&c_uniq_tag=G2SuWwaPCvbOzd-SiRkg0JFRkD_83HyA1hdj7Ty3D14&type=album'},
#      {'height': 87,
#       'type': 'o',
#       'width': 130,
#       'url': 'https://sun7-6.userapi.com/impg/rQtPIBQf0MaOK4_NzR5Xp0l_9yzlZvsnq98Q3Q/rNDwrw7MbPY.jpg?size=130x87&quality=95&sign=9b53eefb478b4e317aaab30eeae179d6&c_uniq_tag=Z7z0qnnsysw8xjDwcGn4_ZRzeqeB5eGhUaZfN1UmD60&type=album'},
#      {'height': 133,
#       'type': 'p',
#       'width': 200,
#       'url': 'https://sun7-6.userapi.com/impg/rQtPIBQf0MaOK4_NzR5Xp0l_9yzlZvsnq98Q3Q/rNDwrw7MbPY.jpg?size=200x133&quality=95&sign=28fe4a849e68fc8f4e4b63fb120987d8&c_uniq_tag=3xgFhbjS3sQwWY-YIdk7uZgcjB3aZ9hihdGr8k2xuxM&type=album'},
#      {'height': 213,
#       'type': 'q',
#       'width': 320,
#       'url': 'https://sun7-6.userapi.com/impg/rQtPIBQf0MaOK4_NzR5Xp0l_9yzlZvsnq98Q3Q/rNDwrw7MbPY.jpg?size=320x213&quality=95&sign=0fe3e2e4d74bb2e96387f340488e6859&c_uniq_tag=DDuRJRezLr9gqirnUO-1WvTbEzXuowi2HcpLlvsEsQ8&type=album'},
#      {'height': 340,
#       'type': 'r',
#       'width': 510,
#       'url': 'https://sun7-6.userapi.com/impg/rQtPIBQf0MaOK4_NzR5Xp0l_9yzlZvsnq98Q3Q/rNDwrw7MbPY.jpg?size=510x340&quality=95&sign=d28cfa3e9591b259efa2300086a057da&c_uniq_tag=aeDs6lwzys8PilrizBe6WpOnqDj1REX5At0MHU_sPpc&type=album'}],
#     'text': '',
#     'user_id': 100}}],
#  'date': 1678260600,
#  'from_id': -22822305,
#  'id': 1390513,
#  'likes': {'can_like': 1,
#   'count': 1041,
#   'user_likes': 0,
#   'can_publish': 1,
#   'repost_disabled': False},
#  'owner_id': -22822305,
#  'post_source': {'type': 'vk'},
#  'post_type': 'post',
#  'reposts': {'count': 78, 'user_reposted': 0},
#  'text': 'К 8 Марта сотрудницы ВКонтакте поделились своими историями — о пути в IT, мечтах изменить мир и борьбе с предрассудками и стереотипами. Читайте вдохновляющую статью на VC: vk.cc/cm64OM.',
#  'views': {'count': 811370}}

# %% [markdown]
# В полях comments, likes и reposts содержится статистика по взаимодействию с сообщением пользователей (на момент получения информации) — число комментариев, лайков и репостов.

# %% [markdown]
# Давайте соберём итоговую статистику для последних десяти непустых сообщений в словарь stats. В качестве ключа будем использовать начало сообщения (если начало сообщения пустое, то информацию о таком сообщении проигнорируем), в качестве значения — список с тремя интересующими нас метриками и временем публикации (комментарии, лайки, репосты, дата публикации):

# %%
stats = {} 
count_post = 0 # Счётчик «непустых» сообщений
for record in response.json()['response']['items'][:]:
    title = record['text'][:30] 
    if title: 
        stats[title] = [record['comments']['count'], record['likes']['count'], record['reposts']['count'], record['date']] 
        count_post += 1 
    if count_post < 10: 
        continue 
    else: 
        break 
pprint(stats)
# Out:
# {'В VK Звонках уже многие успели': [535, 1099, 409, 1675855634],
#  'В начале 2023 года мы запустил': [130, 386, 41, 1678203000],
#  'ВКонтакте продолжает масштабну': [506, 738, 223, 1677585046],
#  'День всех влюблённых приходит ': [458, 1039, 354, 1676355699],
#  'К 8 Марта сотрудницы ВКонтакте': [150, 1041, 78, 1678260600],
#  'Мы посвятим 3D-инсталляцию выд': [89, 471, 70, 1678192985],
#  'Общаемся интерактивнее: в VK М': [194, 1602, 1014, 1677749544],
#  'Объявляем новый VK Fest! В это': [433, 2585, 1369, 1676634000],
#  'Приложение VK Мессенджер — теп': [721, 1226, 790, 1676960293],
#  'Сделайте свой профиль ещё крас': [684, 896, 354, 1677758960]}

# %% [markdown]
# Мы рассмотрели базовое взаимодействие с пользователями и группами. ВКонтакте предоставляет достаточно широкие возможности в своём API: всё, что можно делать вручную через браузер, доступно и в API.
#
# ДОПОЛНИТЕЛЬНО
#
# Если вы размещаете рекламу во ВКонтакте, то можно выгружать всю статистику через [ads API](https://vk.com/dev/ads).
#
# Полный список методов ВКонтакте можно посмотреть в [документации](https://vk.com/dev/methods).
#
#
# ## <center> ДРУГИЕ API
#
# Вы познакомились с интерфейсами прикладного программирования — API (на примере API социальной сети ВКонтакте).
#
# API для разработчиков предоставляют и многие другие платформы. Вот список, пожалуй, самых популярных из них:
#
# * [Google Maps API](https://developers.google.com/maps/)
# * [YouTube API](https://developers.google.com/youtube/)
# * [Twitter API](https://dev.twitter.com/overview/documentation)
# * [Facebook API](https://developers.facebook.com/docs/)
#
# Информацию о сторонних API можно найти в [каталоге Web API](https://www.programmableweb.com/category/all/apis). Также можно воспользоваться интернет-поиском, указав в строке поиска, например, «курсы валют API» или «прогноз погоды api», — среди первых результатов выдачи чаще всего с лёгкостью можно найти ссылки на необходимый функционал.
